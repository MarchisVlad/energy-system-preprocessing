# %%
from BlockStructureAnalyser import ConstraintMatrixAnalyser

problem = ConstraintMatrixAnalyser(mps_path='/homes/vm922/energy-system-preprocessing/models/mps/MIPLIB/10teams.mps')
reduced = ConstraintMatrixAnalyser(mps_path='/homes/vm922/energy-system-preprocessing/models/mps/MIPLIB/reduced10teams.mps')

methods = ['metis', 'spectral', 'rcm']
# Out:
# Coin0001I At line 1 NAME           10teams
# Coin0001I At line 2 ROWS
# Coin0001I At line 234 COLUMNS
# Coin0001I At line 8337 RHS
# Coin0001I At line 8453 BOUNDS
# Coin0001I At line 10479 ENDATA
# Coin0002I Problem 10teams has 230 rows, 2025 columns and 12150 elements
# Coin0008I 10teams read with 0 errors
# Coin0001I At line 7 NAME          10teams.mps
# Coin0001I At line 8 ROWS
# Coin0001I At line 220 COLUMNS
# Coin0001I At line 11423 RHS
# Coin0001I At line 11635 BOUNDS
# Coin0001I At line 13236 ENDATA
# Coin0002I Problem 10teams.mps has 210 rows, 1600 columns and 9600 elements
# Coin0008I 10teams.mps read with 0 errors

# %%
structures = [problem.detect_block_structure(method=method) for method in methods]

for structure in structures:
    problem.plot_block_structure(block_structure=structure)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 structures = [problem.detect_block_structure(method=method) for method in methods]
#       3 for structure in structures:
#       4     problem.plot_block_structure(block_structure=structure)
#
# NameError: name 'methods' is not defined

# %%
structures = [reduced.detect_block_structure(method=method) for method in methods]

for structure in structures:
    reduced.plot_block_structure(block_structure=structure)
