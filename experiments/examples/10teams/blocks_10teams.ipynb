# %%
import sys 
sys.path.append('/homes/vm922/energy-system-preprocessing')
from tools.matrix_analysis.ConstraintMatrixAnalyser import ConstraintMatrixAnalyser

analyser = ConstraintMatrixAnalyser(mps_path='/homes/vm922/energy-system-preprocessing/models/formats/mps/10teams/10teams.mps')
# Out:
# Coin0001I At line 1 NAME           10teams
# Coin0001I At line 2 ROWS
# Coin0001I At line 234 COLUMNS
# Coin0001I At line 8337 RHS
# Coin0001I At line 8453 BOUNDS
# Coin0001I At line 10479 ENDATA
# Coin0002I Problem 10teams has 230 rows, 2025 columns and 12150 elements
# Coin0008I 10teams read with 0 errors

# %%
analyser.print_statistics()
# Out:
# ...
# CONSTRAINT MATRIX STATISTICS
# ...
# Dimensions:           230 × 2025
# Nonzeros:             12,150
# Density:              2.61%
#
# Row statistics:
#   Avg NZ per row:     52.83
#   Min/Max NZ:         45 / 81
#   Std dev:            14.85
#
# Column statistics:
#   Avg NZ per col:     6.00
#   Min/Max NZ:         6 / 6
#   Std dev:            0.00
#
# Coefficient range:
#   Min/Max:            1.00e+00 / 1.00e+00
#   Log10 range:        0.00
# ...

# %%
methods = ['rcm']

structures = [analyser.detect_block_structure(method=method) for method in methods]

for structure in structures:
    analyser.plot_block_structure(block_structure=structure)
    structure.summary()
# Out:
# Block Structure Summary:
#   Detection method: metis
#   Number of blocks: 8
#   Block details:
#     Block 0: rows [0:43] (43), cols [0:333] (333)
#     Block 1: rows [43:84] (41), cols [333:681] (348)
#     Block 2: rows [84:124] (40), cols [681:1216] (535)
#     Block 3: rows [124:162] (38), cols [1216:1664] (448)
#     Block 4: rows [162:197] (35), cols [1664:2022] (358)
#     Block 5: rows [197:208] (11), cols [2022:2023] (1)
#     Block 6: rows [208:219] (11), cols [2023:2024] (1)
#     Block 7: rows [219:230] (11), cols [2024:2025] (1)
#
# Block Structure Summary:
#   Detection method: spectral
#   Number of blocks: 10
#   Block details:
#     Block 0: rows [0:15] (15), cols [0:225] (225)
#     Block 1: rows [15:110] (95), cols [225:2017] (1792)
#     Block 2: rows [110:125] (15), cols [2017:2018] (1)
#     Block 3: rows [125:140] (15), cols [2018:2019] (1)
#     Block 4: rows [140:155] (15), cols [2019:2020] (1)
#     Block 5: rows [155:170] (15), cols [2020:2021] (1)
# ...

# %%
analyser.plot_all_detected_patterns()
# Out:
# Plotting block_diagonal...
#
# Plotting staircase...
# [('block_diagonal',
#   <Figure size 1200x1000 with 1 Axes>,
#   <Axes: title={'center': 'Block Structure Visualization'}, xlabel='Variables (reordered)', ylabel='Constraints (reordered)'>),
#  ('staircase',
#   <Figure size 1200x1000 with 1 Axes>,
#   <Axes: title={'center': 'Block Structure Visualization'}, xlabel='Variables (reordered)', ylabel='Constraints (reordered)'>)]
