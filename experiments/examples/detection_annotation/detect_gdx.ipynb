# %%
import sys 
sys.path.append('/Users/marchisvlad/energy-system-preprocessing')

from src.utils.anops import identify_structure_and_annotate_gdx
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       1 import sys
#       2 sys.path.append('/Users/marchisvlad/energy-system-preprocessing')
# ----> 4 from src.utils.anops import identify_structure_and_annotate_gdx
#
# File ~/energy-system-preprocessing/src/utils/anops/__init__.py:3
#       1 from importlib.metadata import version as _version
# ----> 3 from .annotation import identify_structure_and_annotate_gdx
#       4 from .plotting import plot_gdx
#       6 try:
#
# File ~/energy-system-preprocessing/src/utils/anops/annotation.py:9
#       5 import numpy as np
#       6 import pandas as pd
# ----> 9 from anops.detection import frequency_detection, equation_blocks_from_variables
#      11 os.environ["GDXCOMPRESS"] = "1"
#      14 def find_set_elements(container, pattern_regex, sort_order=None) -> np.array:
#
# ...
